# %% [markdown]
# # Week 1 - Nonlinear Stability Defintions
#
# Week 1 introduces the fundamental concepts of nonlinear stability in dynamical systems and relates them to classical linear stability definitions. The focus is on understanding how stability is defined in the nonlinear setting and how these definitions extend or differ from the linear case.
#
# The module emphasizes the importance of distinguishing between local and global stability, showing how nonlinear systems may behave differently depending on the size of perturbations from equilibrium. These concepts provide the foundation for analyzing spacecraft attitude motion under nonlinear dynamics.
#
# **<ins>Learning Objectives</ins>**
#
# - Differentiate between key nonlinear stability concepts (Lyapunov, asymptotic, exponential)
# - Compare nonlinear stability definitions to their linear counterparts
# - Understand the distinction between local and global stability in nonlinear systems
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.1 - A brief history of controls
#
# Before introducing nonlinear stability concepts, it is useful to recall the core building blocks of classical control theory. These tools form the foundation from which modern and nonlinear methods extend.
#
# The notes below do not delve very deep into the theory. Classical controls on its own require a special attnetion and a study on it is recommended to get a feel for the presentation here (i might create a seperate study in my 'Studies' folder for Controls).

# %% [markdown]
# ## 1.1.1 - Classical Tools

# %% [markdown]
# Early control theory was built around the study of **linear time-invariant (LTI) systems**.
# The central idea was simple but powerful:
#
# > If system dynamics can be approximated as linear differential equations, then calculus can be transformed into algebra.
#
# This transformation made complex engineering systems tractable long before modern computational tools existed.
# Instead of directly solving differential equations, engineers analyzed algebraic expressions in the Laplace domain.
#
#
# **<ins>What makes a system linear?</ins>**
#
# A system is considered **linear** if it satisfies the principle of superposition.
# Intuitively, this means the system treats inputs independently and proportionally.
#
# 1. **Additivity**
#
# If an input $u_1(t)$ produces an output $y_1(t)$ and another input $u_2(t)$ produces an output $y_2(t)$, then applying both inputs together results in the sum of the two responses:
#
# $$
# u(t) = u_1(t) + u_2(t)
# \quad \Rightarrow \quad
# y(t) = y_1(t) + y_2(t).
# $$
#
# 2. **Homogeneity (Scaling)**
#
# If an input $u(t)$ produces an output $y(t)$, then scaling the input by a constant scales the output by the same factor:
#
# $$
# u(t) \to \alpha u(t)
# \quad \Rightarrow \quad
# y(t) \to \alpha y(t).
# $$
#
# Together, these properties imply that the system behaves like a *perfect mixer*:
# inputs can be broken apart, scaled, recombined, and analyzed independently.
#
# This structural property is what makes linear systems mathematically convenient.
#
#
# **<ins>Time Invariance</ins>**
#
# A system is **time-invariant** if its behavior does not depend on *when* an input is applied, only on *what* the input looks like.
#
# If input $x(t)$ produces output $y(t)$, then delaying the input by some amount $T$ produces the same delay in the output:
#
# $$
# x(t - T) \quad \Rightarrow \quad y(t - T).
# $$
#
# In other words, the system does not “age” or change its governing rules over time.
# This assumption allows us to treat the system as fixed and predictable.
#
#
# **<ins>Impulse Response and Convolution</ins>**
#
# A key insight in classical control is that an LTI system can be completely characterized by how it reacts to a very short, sharp input — the **impulse**.
#
# The impulse response $h(t)$ acts as the system’s fingerprint.
#
# For any general input $x(t)$, the output is given by the **convolution integral**:
#
# $$
# y(t) = (x * h)(t) = \int_{-\infty}^{\infty} x(\tau)\, h(t - \tau)\, d\tau .
# $$
#
# This expression is exact, but convolution in the time domain can be cumbersome for analysis and design.
#
#
# **<ins>Laplace Transform and Transfer Functions</ins>**
#
# To simplify analysis, engineers move to the **Laplace domain** (the $s$-domain), where convolution becomes multiplication:
#
# $$
# Y(s) = H(s)\, X(s).
# $$
#
# The system is represented by its **transfer function**:
#
# $$
# G(s) = \frac{Y(s)}{U(s)}.
# $$
#
# In practice, this is written as a rational polynomial:
#
# $$
# G(s) =
# \frac{b_m s^m + \dots + b_1 s + b_0}
#      {a_n s^n + \dots + a_1 s + a_0}.
# $$
#
# The roots of the denominator (**poles**) determine the system’s natural dynamics and stability.
# The roots of the numerator (**zeros**) shape how inputs are transmitted through the system.
#
# This pole-zero representation provides a compact way to reason about system behavior without explicitly solving differential equations.
#
#
# **<ins>Frequency-Domain Techniques</ins>**
#
# Because linear systems preserve sinusoidal structure, inputs at one frequency do not interact with inputs at another frequency.
#
# This allows engineers to analyze behavior frequency-by-frequency using tools such as:
#
# - **Bode plots** — gain and phase versus frequency
# - **Nyquist criterion** — closed-loop stability via encirclement of the $-1$ point
# - **Root locus** — visualization of pole movement as controller gain varies
#
# These tools are powerful precisely because linearity allows global conclusions to be drawn from frequency behavior.
#
# However, most real physical systems are not globally linear.
# When superposition fails or dynamics depend on operating point, the classical framework becomes insufficient.
#
# This motivates the formal study of nonlinear dynamical systems and stability theory.

# %% [markdown]
# ## 1.1.2 - Feedback Control

# %% [markdown]
# The defining idea of modern control is **feedback**.
#
# Instead of commanding a system blindly, we continuously measure its output and compare it to a desired reference. The difference between what we want and what we obtain is called the **error**.
#
# $$
# e(t) = r(t) - y(t)
# $$
#
# where $r(t)$ is the desired reference (command) and $y(t)$ is the measured output.
#
# This error signal is used to compute the control input. In doing so, the controller does more than reduce deviation. It becomes part of the system’s dynamics.
#
# **<ins>Open-loop vs closed-loop behavior</ins>**
#
# In **open-loop control**, the input is applied without observing the output. The system evolves according to its natural dynamics, and disturbances or modeling errors directly affect performance.
#
# In **closed-loop control**, the output is continuously measured and fed back into the input. The plant and controller together form a loop:
#
# reference → controller → plant → output → controller.
#
# The behavior we observe is no longer that of the plant alone. It is the behavior of the combined plant–controller system. Feedback therefore reshapes how the system evolves over time.
#
# **<ins>A canonical example: PID control</ins>**
#
# One widely used classical feedback law is the **Proportional–Integral–Derivative (PID)** controller:
#
# $$
# u(t) = K_p e(t) + K_d \dot{e}(t) + K_i \int e(t)\,dt
# $$
#
# Each term modifies the response in a different way:
#
# - The **Proportional term** reacts to the present error. Increasing $K_p$ generally increases responsiveness but may induce oscillations.
# - The **Derivative term** reacts to the rate of change of error. It adds damping and can improve stability.
# - The **Integral term** accumulates past error. It helps eliminate steady-state offsets caused by persistent disturbances or biases.
#
# PID control illustrates a central idea: by adjusting gains, we alter how the system responds dynamically.
#
# **<ins>Feedback as dynamics reshaping</ins>**
#
# From a systems perspective, feedback modifies the effective equations of motion. In open loop, the plant follows its natural dynamics. In closed loop, the controller alters those dynamics.
#
# For linear systems, this effect is often described as moving the system poles. Conceptually, this means changing:
#
# - How fast the system responds
# - Whether oscillations occur
# - Whether disturbances decay or grow
#
# An unstable open-loop system can often be stabilized through feedback because the controller changes the directions in which the system state naturally evolves.
#
# **<ins>Tradeoffs and practical considerations</ins>**
#
# Feedback introduces design tradeoffs:
#
# - Large gains improve responsiveness but can cause oscillation or instability.
# - Derivative action improves damping but amplifies measurement noise.
# - Integral action removes steady-state error but introduces additional dynamic modes.
#
# These tradeoffs reflect a deeper principle: feedback improves robustness to disturbances and uncertainties, but it must be carefully tuned.
#
# **<ins>Structural limitation</ins>**
#
# Classical feedback analysis relies heavily on linearity and time invariance. Transfer functions, frequency plots, and root locus techniques all depend on these assumptions.
#
# When system behavior becomes strongly nonlinear or varies significantly with operating point, these tools provide only local insight. Stability and performance can no longer be inferred from linear intuition alone.
#
# This limitation motivates the formal study of nonlinear stability theory.

# %% [markdown]
# ## 1.1.3 - State-Space Formulation

# %% [markdown]
# Up to this point, classical control focused mainly on how inputs map to outputs. Transfer functions answered the question:
#
# > If I push the system like this, what comes out?
#
# State space shifts the perspective.
#
# Instead of only tracking input and output, we now describe how the **entire internal configuration of the system evolves over time**.
#
# A linear time-invariant system is written as:
#
# $$
# \dot{x}(t) = A x(t) + B u(t)
# $$
#
# $$
# y(t) = Cx(t) + Du(t)
# $$
#
# Here:
#
# - $x(t)$ is the **state vector**, containing the minimum set of internal variables needed to describe the system at any instant. For a mechanical system, this may be position and velocity. For spacecraft attitude control, it may include orientation and angular rate.
# - $u(t)$ is the control input.
# - $y(t)$ is the measured or regulated output.
# - $A, B, C, D$ are matrices encoding how the system naturally evolves and how inputs influence that evolution.
#
# The key difference is conceptual:
#
# In transfer-function form, the internal motion is hidden.
# In state space, the motion is explicit.
#
# We are no longer asking only how input affects output.
# We are asking how the **state moves in its own space**.
#
#
# **<ins>Stability in State Space</ins>**
#
# For a continuous-time LTI system, the equilibrium $x = 0$ is stable if all eigenvalues of the matrix $A$ have negative real parts.
#
# Geometrically, this means that near the equilibrium, the arrows of the vector field point inward. Any small perturbation shrinks back toward zero.
#
# The powerful part is that stability reduces to an algebraic property of a matrix. We do not need to solve the differential equation explicitly. The eigenvalues tell us how small deviations evolve.
#
# **<ins>Why Eigenvalues Matter</ins>**
#
# The matrix $A$ defines how the state vector moves in time. To understand that motion, we look for special directions in state space where the behavior becomes simple.
#
# An eigenvector of $A$ is one such direction. If the state initially lies along that direction, the dynamics do not bend it elsewhere. The motion remains aligned with it.
#
# The corresponding eigenvalue determines what happens along that direction:
#
# - If the real part is negative, motion along that direction shrinks toward the equilibrium.
# - If the real part is positive, motion grows away from the equilibrium.
# - If the eigenvalue has an imaginary component, the motion involves oscillation or rotation.
#
# In this sense, eigenvalues describe the fundamental modes of motion of the system. Stability requires that all of these modes decay over time.
#
#
# **<ins>Feedback as Dynamics Reshaping</ins>**
#
# Now suppose we apply state feedback:
#
# $$
# u = -Kx.
# $$
#
# Substituting into the state equation gives:
#
# $$
# \dot{x} = (A - BK)x.
# $$
#
# This equation reveals something fundamental. Feedback does not merely reduce error. It modifies the matrix that governs how the state evolves.
#
# In geometric terms, we are reshaping the vector field in state space. We can change how fast trajectories decay, whether they spiral or move straight inward, and whether disturbances grow or vanish.
#
# This is why pole placement works. We are directly altering the directions and magnitudes that define the system’s motion.
#
#
# **<ins>Design Methods</ins>**
#
# Two classical design approaches naturally arise from this framework:
#
# - **Pole placement**, which selects $K$ so that the closed-loop eigenvalues lie in desired locations.
# - **Linear Quadratic Regulator (LQR)**, which computes $K$ by minimizing a quadratic cost that balances state deviation and control effort.
#
# These methods scale well to high-dimensional and multi-input multi-output systems, which makes them especially useful in aerospace applications.
#
#
# **<ins>Bridge to Nonlinear Systems</ins>**
#
# The state-space formulation also extends naturally to nonlinear systems:
#
# $$
# \dot{x} = f(x, u, t).
# $$
#
# The structure of the equation remains similar, but the matrix $A$ is replaced by a nonlinear function. In that setting, eigenvalues alone are no longer sufficient to determine stability. The geometry of the vector field itself becomes central.
#
# This is where nonlinear stability theory begins.

# %%
from scipy.linalg import expm
# ======================================================
# Demonstration:  x_dot = A x
#
# This cell visualizes how the matrix A determines motion.
#
# For a 2x2 system:
#
#     A = [[a,  b],
#          [c,  d]]
#
# The diagonal terms (a, d) primarily control stretching
# or shrinking along coordinate directions.
#
# The off-diagonal terms (b, c) couple x1 and x2:
#   - If b and c have opposite signs (like [[0, w],[-w,0]]),
#     the system produces rotation.
#   - If they reinforce stretching in one direction,
#     you may get a saddle.
#
# The eigenvalues of A summarize the combined effect:
#
#   λ = real part  → exponential growth (+) or decay (-)
#   λ = imaginary part → rotation frequency
#
# Eigenvectors are special directions v such that:
#
#     A v = λ v
#
# If the state starts along an eigenvector,
# it never bends away — it only scales by e^{λ t}.
#
# Change A and re-run to see how the geometry changes.
#
# Suggested matrices:
#
# Stable node:
# A = np.array([[-1.0,  0.0],
#               [ 0.0, -0.4]])
#
# Saddle:
# A = np.array([[ 0.8,  0.0],
#               [ 0.0, -0.6]])
#
# Stable spiral:
# A = np.array([[-0.3,  1.2],
#               [-1.2, -0.3]])
#
# Unstable spiral:
# A = np.array([[ 0.3,  1.2],
#               [-1.2,  0.3]])
# ======================================================

A = np.array([[ 0.3,  1.2],
              [-1.2,  0.3]])

eigvals = np.linalg.eigvals(A)

print("A =\n", A)
print("\nEigenvalues:")
for i, lam in enumerate(eigvals, start=1):
    print(f"  λ{i} = {lam.real:+.3f} {lam.imag:+.3f}j")

# Initial condition
x0 = np.array([2.0, 0.0])

# Time vector
t = np.linspace(0, 10, 400)

# Exact solution: x(t) = e^{At} x0
X = np.array([expm(A * ti) @ x0 for ti in t])

x1 = X[:, 0]
x2 = X[:, 1]
norm = np.sqrt(x1**2 + x2**2)

# Plot
fig, axs = plt.subplots(1, 2, figsize=(10, 4))
lim = 5.0

# Phase portrait
axs[0].plot(x1, x2)
axs[0].plot(0, 0, 'ko')
axs[0].set_title("Phase Portrait")
axs[0].set_xlabel("$x_1$")
axs[0].set_ylabel("$x_2$")
axs[0].set_aspect("equal")
axs[0].set_xlim([-lim, lim])
axs[0].set_ylim([-lim, lim])
axs[0].grid(True)

# Time response
axs[1].plot(t, x1, label="$x_1$")
axs[1].plot(t, x2, linestyle='--', label="$x_2$")
axs[1].plot(t, norm, color='black', linewidth=2, label=r"$\|x(t)\|$")
axs[1].set_title("Time Response")
axs[1].set_xlabel("Time")
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# A =
#  [[ 0.3  1.2]
#  [-1.2  0.3]]
#
# Eigenvalues:
#   λ1 = +0.300 +1.200j
#   λ2 = +0.300 -1.200j

# %% [markdown]
# ## 1.1.4 - Limitations of Classical Control

# %% [markdown]
# Despite their remarkable success, classical linear control methods are fundamentally **local in nature**.
#
# They work extremely well near a chosen operating point, where system behavior can be approximated as linear. However, as the system moves away from that region, the assumptions underlying linear analysis begin to weaken.
#
# Linearization about an equilibrium provides only **local stability guarantees**, valid in a small neighborhood around that equilibrium. The further the system state drifts, the less accurate the linear approximation becomes.
#
# For spacecraft systems, this limitation is not merely theoretical. Attitude dynamics evolve on the nonlinear manifold $SO(3)$, where orientations wrap around and cannot be represented globally using linear coordinates. Large-angle maneuvers, actuator saturation, and strongly coupled rotational dynamics expose regimes where linear tools may become unreliable or even misleading.
#
# The issue is not that classical methods are incorrect. It is that they are built upon structural assumptions: superposition, fixed operating points, and small deviations.
#
# When those assumptions fail, so do the guarantees.
#
# Nonlinear control addresses these challenges by working directly with the nonlinear equations of motion:
#
# $$
# \dot{x} = f(x, u, t).
# $$
#
# Instead of approximating locally, the analysis is performed on the full nonlinear system. This enables:
#
# - Stability results that may hold globally or almost globally, depending on system topology.
# - Controllers that remain valid across large attitude ranges, not just near a single equilibrium.
# - Energy-based and geometric approaches, such as Lyapunov methods, that reason directly about system behavior rather than local linear properties.
#
# **<ins>Takeaway</ins>**
#
# Classical control theory provides essential intuition and powerful mathematical tools. It forms the foundation of modern control design.
#
# However, realistic spacecraft dynamics demand methods that go beyond local linear analysis. To guarantee stability and performance during large-angle maneuvers and strongly nonlinear motion, we must move beyond eigenvalues and frequency plots.
#
# This motivates the study of nonlinear stability and nonlinear feedback control.
#
# **<ins>Note</ins>**
#
# Nonlinear control does not replace classical control. It extends it.
#
# The same core principles remain, but the analysis and design tools are adapted to handle nonlinear geometry, large motions, and regimes where linear approximations no longer hold.

# %% [markdown]
# # 1.2 - Mathematical Language of Nonlinear Systems

# %% [markdown]
# ## 1.2.1 - Dynamical Systems

# %% [markdown]
# Before discussing stability, we need a precise way to describe how systems evolve in time.
#
# At its core, a **dynamical system** is simply a rule that tells us how the state changes.
#
# Let the state vector be
#
# $$
# x = (x_1, \dots, x_N)^T.
# $$
#
# The state collects the minimum set of variables required to fully describe the system at any instant.
# For a mechanical system, this may be position and velocity.
# For spacecraft attitude motion, it may include orientation parameters and angular velocity.
#
# Once the state is known, the future motion is determined by the **equations of motion (EOM)**.
#
#
# **<ins>Autonomous system</ins>**
#
# A nonlinear autonomous system is written as:
#
# $$
# \dot{x} = f(x).
# $$
#
# Here, the function $f(x)$ assigns a velocity vector to every point in state space.
#
# Geometrically, this equation defines a **vector field**.
# At every point $x$, there is an arrow $\dot{x}$ indicating the direction and rate at which the state moves.
#
# A trajectory is obtained by placing the system at an initial state $x(t_0)$ and following these arrows forward in time.
#
#
# **<ins>Non-autonomous system</ins>**
#
# If the dynamics depend explicitly on time, we write:
#
# $$
# \dot{x} = f(x, t).
# $$
#
# In this case, the vector field itself changes with time.
# The arrows can stretch, rotate, or reshape as time progresses.
#
# Many practical systems fall into this category when parameters or inputs vary over time.
#
#
# **<ins>Controlled system</ins>**
#
# When a control input is present, the system becomes
#
# $$
# \dot{x} = f(x, u, t),
# $$
#
# where $u$ represents actuator inputs or commanded forces and torques.
#
# If the control law is chosen as a function of the state,
#
# $$
# u = g(x),
# $$
#
# then substituting this into the dynamics yields the **closed-loop system**
#
# $$
# \dot{x} = f(x, g(x)).
# $$
#
# Notice something important:
#
# Once the control law is applied, the system is again autonomous.
# Its future evolution depends only on its current state.
#
# This viewpoint is central to nonlinear stability analysis.
# We do not study inputs and outputs separately; we study how the **state evolves under the closed-loop dynamics**.
#
#
# **In summary:**
#
# A dynamical system is a rule that assigns motion to every point in state space. Understanding stability means understanding how these motion rules behave near special states, which we introduce next.

# %% [markdown]
# ## 1.2.2 - Equilibrium States

# %% [markdown]
# Given a dynamical system
#
# $$
# \dot{x} = f(x),
# $$
#
# an **equilibrium state** (or equilibrium point) $x_e$ is defined as a state that satisfies
#
# $$
# f(x_e) = 0.
# $$
#
# This means
#
# $$
# \dot{x}_e = 0,
# $$
#
# so if the system is initialized at $x_e$, it remains there for all future time.
#
#
# **<ins>Geometric interpretation</ins>**
#
# Recall that $f(x)$ defines a vector field.
# At every point in state space, there is an arrow indicating the direction of motion.
#
# An equilibrium state is a point where that arrow vanishes.
#
# There is no motion.
# The system, if placed exactly there, does not move.
#
#
# **<ins>Important observation</ins>**
#
# An equilibrium being motionless does *not* automatically mean it is stable.
#
# Some equilibria attract nearby trajectories.
# Some repel them.
# Some attract in certain directions and repel in others.
#
# The classification of these behaviors is the subject of stability analysis.
#
#
# **<ins>Reference trajectories</ins>**
#
# While equilibria are constant solutions, stability can also be defined relative to a time-varying reference trajectory $x_r(t)$ satisfying
#
# $$
# \dot{x}_r = f(x_r).
# $$
#
# In this case, $x_r(t)$ itself is a solution of the system.
#
# Equilibria are simply the special case where the reference trajectory is constant in time.
#
#
# **In summary:**
#
# An equilibrium is a state where the system would remain indefinitely if undisturbed.
# Stability theory asks a deeper question:
#
# What happens if the system is slightly perturbed away from that state?

# %% [markdown]
# ## 1.2.3 - Neighborhoods and Perturbations

# %% [markdown]
# Stability is not about motion in isolation.
# It is about how motion behaves when the system is slightly disturbed from the reference state.
#
# To make this precise, we need a mathematical notion of *closeness* in state space.
#
# **<ins>Norm and distance</ins>**
#
# Let $\|\cdot\|$ denote a norm on the state space.
# In most engineering applications, this is the Euclidean norm:
#
# $$
# \|x\| = \sqrt{x_1^2 + \dots + x_N^2}.
# $$
#
# The distance between two states $x$ and $x_r$ is then
#
# $$
# \|x - x_r\|.
# $$
#
# This gives us a quantitative measure of how far one state is from another.
#
#
# **<ins>Neighborhood (Ball) Around a State</ins>**
#
# <div align="center">
#   <img src="Images/Wk1_Neighborhood.PNG" alt="Alt text" width="500"/>
# </div>
#
# Given a radius $\delta > 0$, the **neighborhood** (or open ball) of radius $\delta$ centered at a reference state $x_r$ is defined as
#
# $$
# B_\delta(x_r) = \{ x \in \mathbb{R}^N \mid \|x - x_r\| < \delta \}.
# $$
#
# Geometrically, this is a bubble of radius $\delta$ around $x_r$.
#
# If the system state satisfies
#
# $$
# x(t) \in B_\delta(x_r),
# $$
#
# then it lies inside this bubble.
#
#
# **<ins>Perturbations</ins>**
#
# Suppose the system is initialized near an equilibrium $x_e$.
# We define the **perturbation state**
#
# $$
# \tilde{x}(t) = x(t) - x_e.
# $$
#
# If $\|\tilde{x}(t_0)\|$ is small, we say the system has been slightly disturbed from equilibrium.
#
# The central question of stability theory is:
#
# If the system starts inside some small neighborhood of $x_e$,
# does it remain inside that neighborhood?
# Does it return to $x_e$?
# Or does it move away?
#
#
# **In summary:**
#
# Neighborhoods provide the geometric language needed to formalize statements such as “starting close” and “remaining close.”
#
# With this language in place, we can now rigorously define different types of stability.

# %% [markdown]
# # 1.3 - Types of Stability

# %% [markdown]
# ## 1.3.1 - Lagrange Stability (Boundedness)

# %% [markdown]
# <div align="center">
#   <img src="Images/Wk1_LagrangeStability.PNG" alt="Alt text" width="500"/>
# </div>
#
# Lagrange stability formalizes the idea that a system’s motion remains **bounded** over time.
#
# Consider a dynamical system
#
# $$
# \dot{x} = f(x),
# $$
#
# and a reference trajectory $x_r(t)$.
#
# The motion $x(t)$ is said to be **Lagrange stable** relative to $x_r(t)$ if there exists a constant $\delta > 0$ such that
#
# $$
# x(t) \in B_\delta(x_r(t)) \quad \forall \, t \ge t_0.
# $$
#
# In other words, the state remains inside some fixed neighborhood of radius $\delta$ for all future time.
#
# **<ins>Understanding the definition</ins>**
#
# The key feature is the existence of a single finite bound $\delta$.
#
# There must be some region around the reference trajectory such that once the motion enters this region, it never leaves it.
#
# The size of the region is fixed in advance.
# The definition does not require the region to be arbitrarily small.
#
# **<ins>Geometric interpretation</ins>**
#
# Imagine placing a bubble of fixed radius $\delta$ around the reference trajectory.
#
# If the system’s motion never leaves that bubble, it is Lagrange stable.
#
# The size of the bubble is fixed in advance.
# The trajectory may wander inside it, oscillate, or drift within its interior, but it does not escape.
#
#
# **<ins>What Lagrange stability guarantees</ins>**
#
# - The motion is bounded.
# - The state does not diverge to infinity.
# - The trajectory remains confined within a finite region.
#
#
# **<ins>What Lagrange stability does *not* guarantee</ins>**
#
# - The state does not have to remain arbitrarily close to the reference.
# - The state does not have to converge to the reference.
# - The trajectory may continue oscillating indefinitely inside the bubble.
#
# For example, a simple undamped harmonic oscillator is Lagrange stable:
# its motion remains bounded, but it never converges to equilibrium.
#
#
# **In summary:**
#
# Lagrange stability ensures boundedness of motion over time.
# It is a necessary property for many physical systems, but it is weaker than Lyapunov or asymptotic stability.

# %% [markdown]
# ## 1.3.2 - Lyapunov Stability (Remains Close)

# %% [markdown]
# <div align="center">
#   <img src="Images/Wk1_LyapunovStability.PNG" alt="Alt text" width="500"/>
# </div>
#
# Lyapunov stability formalizes the idea that trajectories which start **sufficiently close** to a reference state remain **arbitrarily close** for all future time.
#
# Consider the system
#
# $$
# \dot{x} = f(x),
# $$
#
# and a reference trajectory $x_r(t)$.
#
# The motion $x(t)$ is said to be **Lyapunov stable** relative to $x_r(t)$ if, for every tolerance $\epsilon > 0$, there exists a corresponding distance $\delta(\epsilon) > 0$ such that
#
# $$
# x(t_0) \in B_\delta(x_r(t_0)) \;\Rightarrow\; x(t) \in B_\epsilon(x_r(t)) \quad \forall \, t \ge t_0.
# $$
#
# **<ins>Understanding the definition</ins>**
#
# The key structure is:
#
# - You first choose how close you want the motion to remain (this is $\epsilon$).
# - Then there exists a sufficiently small neighborhood of initial conditions (this is $\delta$).
# - Any trajectory starting inside that smaller neighborhood will never leave the larger $\epsilon$-neighborhood.
#
# The important feature is that $\delta$ depends on $\epsilon$.
#
# You specify the allowable closeness first.
# The system must then guarantee that closeness through appropriate initial conditions.
#
#
# **<ins>Geometric interpretation</ins>**
#
# Imagine drawing a small bubble of radius $\epsilon$ around the reference trajectory.
#
# Lyapunov stability says that if the system starts inside an even smaller bubble of radius $\delta$, it will remain inside the larger $\epsilon$ bubble for all time.
#
# The trajectory may move within the bubble.
# It may oscillate or wander.
# But it will not escape beyond the tolerance you prescribed.
#
#
# **<ins>How this differs from Lagrange stability</ins>**
#
# - Lagrange stability guarantees boundedness inside *some* fixed region.
# - Lyapunov stability guarantees closeness at a prescribed level.
# - The system does not have to converge to the reference.
# - The motion may persist indefinitely without approaching the equilibrium.
#
# For example, an undamped harmonic oscillator centered at the origin is Lyapunov stable.
# Small perturbations remain small, but the motion never decays to zero.
#
#
# **In summary:**
#
# Lyapunov stability guarantees that sufficiently small perturbations remain small for all future time.
# It ensures preservation of closeness, but not convergence.

# %% [markdown]
# ## 1.3.3 - Asymptotic Stability (Converge)

# %% [markdown]
# <div align="center">
#   <img src="Images/Wk1_AsymptoticStability.PNG" alt="Alt text" width="500"/>
# </div>
#
# Asymptotic stability strengthens Lyapunov stability by additionally requiring **convergence** to the reference state or trajectory over time.
#
# Consider the system
#
# $$
# \dot{x} = f(x),
# $$
#
# and a reference trajectory $x_r(t)$.
#
# The motion $x(t)$ is said to be **asymptotically stable** relative to $x_r(t)$ if:
#
# 1. $x(t)$ is **Lyapunov stable**, and
# 2. There exists a distance $\delta > 0$ such that
#
# $$
# x(t_0) \in B_\delta(x_r(t_0)) \;\Rightarrow\; \lim_{t \to \infty} x(t) = x_r(t).
# $$
#
#
# **<ins>Understanding the definition</ins>**
#
# Asymptotic stability contains two ingredients:
#
# - Small perturbations remain small (Lyapunov stability).
# - Small perturbations eventually decay to zero (convergence).
#
# The second condition guarantees that trajectories starting sufficiently close to the reference will approach it as time progresses.
#
# The constant $\delta$ defines a neighborhood of initial conditions from which convergence is assured.
#
#
# **<ins>Geometric interpretation</ins>**
#
# Imagine again drawing a bubble around the reference trajectory.
#
# Lyapunov stability ensures trajectories never leave that bubble.
#
# Asymptotic stability goes further: trajectories spiral, drift, or move inward until they settle at the reference itself.
#
# The distance between the system state and the reference shrinks over time:
#
# $$
# \|x(t) - x_r(t)\| \to 0 \quad \text{as} \quad t \to \infty.
# $$
#
#
# **<ins>How this differs from Lyapunov stability</ins>**
#
# - Lyapunov stability guarantees preservation of closeness.
# - Asymptotic stability guarantees preservation of closeness **and** eventual convergence.
# - The trajectory does not merely remain near the reference; it approaches it.
#
# For example, a damped harmonic oscillator is asymptotically stable at the origin.
# Small perturbations not only remain small, but decay until the system settles at equilibrium.
#
#
# **In summary:**
#
# Asymptotic stability ensures that sufficiently small perturbations both remain small and vanish over time.
# It combines short-term boundedness with long-term convergence.

# %% [markdown]
# ## 1.3.4 - Global Stability (Scope)

# %% [markdown]
# <div align="center">
#   <img src="Images/Wk1_GlobalStability.PNG" alt="Alt text" width="500"/>
# </div>
#
# Global stability extends the previous notions of stability by enlarging the set of allowable initial conditions.
#
# Consider the system
#
# $$
# \dot{x} = f(x),
# $$
#
# and a reference trajectory $x_r(t)$.
#
# The motion $x(t)$ is said to be **globally stable** relative to $x_r(t)$ if the corresponding stability property (such as Lyapunov stability or asymptotic stability) holds for **all admissible initial conditions** $x(t_0)$ in the state space.
#
# In other words, the guarantees are no longer restricted to a small neighborhood of the reference.
#
#
# **<ins>Understanding the definition</ins>**
#
# In previous definitions, we required the initial state to lie inside some neighborhood $B_\delta(x_r(t_0))$.
#
# Global stability removes this restriction.
#
# The qualitative behavior — remaining close or converging — must hold regardless of where the motion begins.
#
# If convergence to the reference is guaranteed for all initial conditions, the system is said to be **globally asymptotically stable**.
#
#
# **<ins>Geometric interpretation</ins>**
#
# Local stability examines behavior near the equilibrium.
#
# Global stability examines the entire state space.
#
# It asks:
#
# Do all trajectories eventually behave well?
# Or does the system behave differently when far from equilibrium?
#
# Nonlinear systems often exhibit dramatically different behavior far from the origin, even if they appear well behaved locally.
#
#
# **<ins>Example</ins>**
#
# A damped pendulum is globally asymptotically stable at the downward equilibrium.
# From any initial angle and angular velocity, the motion eventually settles at the bottom position.
#
# However, many nonlinear systems are only locally stable.
# Far from equilibrium, nonlinear effects can dominate, leading to divergence, oscillations, or alternative equilibria.
#
#
# **In summary:**
#
# Global stability strengthens previous stability notions by requiring their guarantees to hold over the entire state space.
# It is a powerful property, but often difficult to establish for nonlinear systems.

# %% [markdown]
# # 1.4 - Linearization as a Local Stability analysis tool

# %% [markdown]
# Nonlinear systems are generally difficult to analyze directly.
# However, if the system dynamics are smooth, then near a reference motion the nonlinear vector field behaves approximately like a linear one.
#
# Linearization provides a first-order approximation of the nonlinear dynamics in a neighborhood of a reference state or trajectory.
# This allows us to use linear tools — especially eigenvalue analysis — to assess **local stability**.

# %% [markdown]
# ## 1.4.1 - Linearization about an Equilibrium

# %% [markdown]
# Consider a nonlinear system
#
# $$
# \dot{x} = f(x,u).
# $$
#
# Let $(x_r(t), u_r(t))$ be a nominal reference motion that satisfies the nonlinear equations of motion:
#
# $$
# \dot{x}_r = f(x_r, u_r).
# $$
#
# We are not interested in the full motion itself, but in how small deviations from the reference evolve.
#
# Define the **departure (perturbation) variables**
#
# $$
# \delta x = x - x_r,
# \qquad
# \delta u = u - u_r.
# $$
#
# Substituting $x = x_r + \delta x$ and $u = u_r + \delta u$ into the nonlinear dynamics gives
#
# $$
# \dot{x} = f(x_r + \delta x,\; u_r + \delta u).
# $$
#
# The evolution of the deviation is
#
# $$
# \delta \dot{x} = \dot{x} - \dot{x}_r.
# $$
#
# We now perform a Taylor expansion of $f(x,u)$ about $(x_r, u_r)$:
#
# $$
# f(x_r + \delta x,\; u_r + \delta u)
# \approx
# f(x_r, u_r)
# +
# \frac{\partial f(x_r, u_r)}{\partial x}\, \delta x
# +
# \frac{\partial f(x_r, u_r)}{\partial u}\, \delta u
# +
# \text{H.O.T.}
# $$
#
# Substituting into the deviation dynamics yields
#
# $$
# \delta \dot{x} =
# \Big[
# f(x_r, u_r) +
# \frac{\partial f(x_r, u_r)}{\partial x}\, \delta x +
# \frac{\partial f(x_r, u_r)}{\partial u}\, \delta u +
# \text{H.O.T.}
# \Big] -
# f(x_r, u_r).
# $$
#
# The constant terms cancel because the reference motion satisfies the original equations of motion.
# Neglecting higher-order terms (valid for sufficiently small deviations), we obtain the linear approximation
#
# $$
# \delta \dot{x} \simeq
# \frac{\partial f(x_r, u_r)}{\partial x}\, \delta x
# +
# \frac{\partial f(x_r, u_r)}{\partial u}\, \delta u.
# $$
#
# Define the Jacobian matrices
#
# $$
# [A] = \frac{\partial f(x_r, u_r)}{\partial x},
# \qquad
# [B] = \frac{\partial f(x_r, u_r)}{\partial u}.
# $$
#
# The **linearized system** governing small perturbations is therefore
#
# $$
# \delta \dot{x} \simeq [A]\, \delta x + [B]\, \delta u.
# $$
#
# If the reference motion is an equilibrium $(x_e, u_e)$ such that $f(x_e, u_e) = 0$, then the perturbation variables coincide with the state itself and the system reduces to
#
# $$
# \dot{x} \simeq [A]\, x + [B]\, u.
# $$

# %% [markdown]
# ## 1.4.2 - Local Error Dynamics

# %% [markdown]
# The matrix $[A]$ is the **Jacobian of the vector field** evaluated at the reference motion.
#
# Geometrically, it describes how the nonlinear vector field changes with respect to the state near that point.
# It is the best linear approximation of the nonlinear dynamics in a neighborhood of the reference.
#
# Thus, near an equilibrium, the nonlinear system behaves approximately like the linear system
#
# $$
# \dot{x} = A x.
# $$
#
# This is why eigenvalues appear naturally in nonlinear stability analysis:
# locally, the nonlinear system behaves like a linear one.

# %% [markdown]
# ## 1.4.3 - Stability of the Linearized System

# %% [markdown]
# For the linear system
#
# $$
# \dot{x} = A x,
# $$
#
# stability is determined entirely by the eigenvalues of $A$:
#
# - If all eigenvalues have strictly negative real parts, the origin is asymptotically stable.
# - If any eigenvalue has a positive real part, the origin is unstable.
#
# The fundamental result of linearization theory states:
#
# If the linearized system about an equilibrium is asymptotically stable, then the equilibrium of the nonlinear system is **locally asymptotically stable**.
#
# If the linearized system is unstable, then the nonlinear equilibrium is unstable.
#
# Thus, eigenvalues of the Jacobian determine **local stability** of nonlinear systems.

# %% [markdown]
# ## 1.4.4 - What Linearization can and cannot tell us

# %% [markdown]
# Linearization is a first-order approximation.
# It neglects higher-order nonlinear terms.
#
# As a result:
#
# - Stability conclusions are valid only within a neighborhood of the equilibrium.
# - The size of this neighborhood is generally unknown.
# - Linearization provides no guarantees about global behavior.
#
# A nonlinear system may appear stable when linearized near an equilibrium, yet exhibit limit cycles, multiple equilibria, or divergence far from that point.
#
# Linearization is therefore a **local analysis tool**, not a global one.

# %% [markdown]
# ## 1.4.5 - Geometric Interpretation

# %% [markdown]
# Linearization replaces the nonlinear vector field with its tangent approximation at the equilibrium.
#
# Zoom in sufficiently close to a smooth equilibrium point, and the nonlinear dynamics resemble a linear system.
# Zoom out, and nonlinear curvature becomes dominant.
#
# In this sense, linearization acts like a microscope:
# it reveals local behavior with clarity, but cannot describe the full global structure of the state space.
#
# This limitation motivates nonlinear stability tools, such as Lyapunov methods, which reason directly about the full nonlinear dynamics.

# %% [markdown]
# ---
#
# Notes compiled and structured by John Gracious
